# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv("~\Documents\IOD-testing\DATA\Employee-attrition.csv")

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
df.info
# Out:
# <bound method DataFrame.info of        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 4                1/1/1900   56                 21    Vancouver
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 0             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 4             Executive           CEO          35            M        Male
# ...                 ...           ...         ...          ...         ...
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# ...               ...             ...          ...         ...           ...
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
#
# [49653 rows x 18 columns]>

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
df['job_title'].unique()
# Out:
# array(['CEO', 'VP Stores', 'Legal Counsel', 'VP Human Resources',
#        'VP Finance', 'Exec Assistant, VP Stores',
#        'Exec Assistant, Legal Counsel', 'CHief Information Officer',
#        'Store Manager', 'Meats Manager',
#        'Exec Assistant, Human Resources', 'Exec Assistant, Finance',
#        'Director, Recruitment', 'Director, Training',
#        'Director, Labor Relations', 'Director, HR Technology',
#        'Director, Employee Records', 'Director, Compensation',
#        'Corporate Lawyer', 'Produce Manager',
#        'Director, Accounts Receivable', 'Bakery Manager',
#        'Systems Analyst', 'Director, Accounts Payable', 'Director, Audit',
#        'Director, Accounting', 'Director, Investments', 'Dairy Person',
#        'Recruiter', 'Processed Foods Manager', 'Customer Service Manager',
#        'Trainer', 'Meat Cutter', 'Labor Relations Analyst',
#        'Dairy Manager', 'HRIS Analyst', 'Benefits Admin',
#        'Compensation Analyst', 'Accounts Receiveable Clerk',
#        'Accounts Payable Clerk', 'Baker', 'Auditor', 'Accounting Clerk',
#        'Investment Analyst', 'Produce Clerk', 'Shelf Stocker', 'Cashier'],
#       dtype=object)

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# CEO                                  10
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Stores                            10
# VP Human Resources                   10
# VP Finance                           10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Exec Assistant, Legal Counsel        10
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounting                  9
# Director, Investments                 4
# Director, Labor Relations             4
# Director, Compensation                4
# Director, Audit                       4
# Director, Training                    4
# Name: job_title, dtype: int64

# %% [markdown]
#  2.C [BONUS] Write A Function to Row Count

# %%
def row_count(column_name):
    number_of_rows = df[column_name].value_counts()
    return number_of_rows

# %%
row_count('city_name')
# Out:
# Vancouver           11211
# Victoria             4885
# Nanaimo              3876
# New Westminster      3211
# Kelowna              2513
# Burnaby              2067
# Kamloops             2061
# Prince George        2048
# Cranbrook            1785
# Surrey               1560
# Richmond             1401
# Terrace              1228
# Chilliwack           1167
# Trail                 925
# Langley               901
# Vernon                898
# Squamish              806
# Quesnel               703
# Abbotsford            681
# North Vancouver       648
# Fort St John          621
# Williams Lake         617
# West Vancouver        613
# Port Coquitlam        545
# Aldergrove            520
# Fort Nelson           322
# Nelson                317
# New Westminister      254
# Grand Forks           236
# White Rock            231
# Haney                 182
# Princeton             136
# Dawson Creek          129
# Bella Bella           126
# Ocean Falls            65
# Pitt Meadows           57
# Cortes Island          43
# Valemount              37
# Dease Lake             18
# Blue River              9
# Name: city_name, dtype: int64

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
df.set_index('EmployeeID', inplace=True)

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
df[df.index==5831]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 5831        12/31/2006 0:00     5/25/1975         8/5/2003
# 5831        12/31/2007 0:00     5/25/1975         8/5/2003
# 5831        12/31/2008 0:00     5/25/1975         8/5/2003
# 5831        12/31/2009 0:00     5/25/1975         8/5/2003
# 5831        12/31/2010 0:00     5/25/1975         8/5/2003
# 5831        12/31/2011 0:00     5/25/1975         8/5/2003
# 5831        12/31/2012 0:00     5/25/1975         8/5/2003
# 5831        12/31/2013 0:00     5/25/1975         8/5/2003
# 5831        12/31/2014 0:00     5/25/1975         8/5/2003
# 5831        12/31/2015 0:00     5/25/1975         8/5/2003
#
#            terminationdate_key  age  length_of_service city_name  \
# EmployeeID
# 5831                  1/1/1900   31                  3    Vernon
# 5831                  1/1/1900   32                  4    Vernon
# 5831                  1/1/1900   33                  5    Vernon
# 5831                  1/1/1900   34                  6    Vernon
# 5831                  1/1/1900   35                  7    Vernon
# 5831                  1/1/1900   36                  8    Vernon
# 5831                  1/1/1900   37                  9    Vernon
# 5831                  1/1/1900   38                 10    Vernon
# 5831                  1/1/1900   39                 11    Vernon
# 5831                  1/1/1900   40                 12    Vernon
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
# 5831                 Dairy  Dairy Person          36            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 5831        Not Applicable  Not Applicable         2006  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2007  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2008  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2009  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2010  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2011  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2012  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2014  ACTIVE        STORES
# 5831        Not Applicable  Not Applicable         2015  ACTIVE        STORES

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
df.sort_index()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8335        12/31/2013 0:00    12/28/1994       12/10/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# ...                        ...  ...                ...        ...
# 8335                  1/1/1900   19                  0  Vancouver
# 8335                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   19                  0  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# ...                    ...           ...         ...          ...         ...
# 8335                 Dairy  Dairy Person          35            F      Female
# 8335                 Dairy  Dairy Person          35            F      Female
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# ...                    ...             ...          ...     ...           ...
# 8335        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2014  ACTIVE        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
df.sort_values(by='age')
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8325        12/31/2013 0:00     12/7/1994       11/29/2013
# 8253        12/31/2013 0:00     5/15/1994        8/12/2013
# 8252        12/31/2013 0:00     5/10/1994         8/9/2013
# 8251        12/31/2013 0:00      5/7/1994         8/7/2013
# 8250        12/31/2013 0:00     4/26/1994         8/2/2013
# ...                     ...           ...              ...
# 3262          8/1/2008 0:00     8/23/1943        2/28/1995
# 3248          8/1/2008 0:00     8/14/1943        2/19/1995
# 4948          7/1/2013 0:00      7/9/1948        1/14/2000
# 3356         11/1/2008 0:00    11/18/1943        5/26/1995
# 4138          2/1/2011 0:00     2/12/1946        8/20/1997
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 8325                  1/1/1900   19                  0        Cranbrook
# 8253                  1/1/1900   19                  0  North Vancouver
# 8252                  1/1/1900   19                  0         Victoria
# 8251                  1/1/1900   19                  0        Vancouver
# 8250                  1/1/1900   19                  0          Burnaby
# ...                        ...  ...                ...              ...
# 3262                 8/23/2008   65                 13          Nanaimo
# 3248                 8/14/2008   65                 13        Vancouver
# 4948                  7/9/2013   65                 13          Burnaby
# 3356                11/18/2008   65                 13          Nanaimo
# 4138                 2/12/2011   65                 13           Surrey
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 8325        Customer Service        Cashier           8            M
# 8253        Customer Service        Cashier          22            F
# 8252        Customer Service        Cashier          46            F
# 8251        Customer Service        Cashier          44            F
# 8250                   Dairy   Dairy Person           5            F
# ...                      ...            ...         ...          ...
# 3262                   Meats    Meat Cutter          18            F
# 3248                   Dairy   Dairy Person          35            F
# 4948                 Produce  Produce Clerk           5            F
# 3356                   Meats    Meat Cutter          18            F
# 4138                 Produce  Produce Clerk          31            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 8325              Male  Not Applicable  Not Applicable         2013
# 8253            Female  Not Applicable  Not Applicable         2013
# 8252            Female  Not Applicable  Not Applicable         2013
# 8251            Female  Not Applicable  Not Applicable         2013
# 8250            Female  Not Applicable  Not Applicable         2013
# ...                ...             ...             ...          ...
# 3262            Female      Retirement       Voluntary         2008
# 3248            Female      Retirement       Voluntary         2008
# 4948            Female      Retirement       Voluntary         2013
# 3356            Female      Retirement       Voluntary         2008
# 4138            Female      Retirement       Voluntary         2011
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 8325            ACTIVE        STORES
# 8253            ACTIVE        STORES
# 8252            ACTIVE        STORES
# 8251            ACTIVE        STORES
# 8250            ACTIVE        STORES
# ...                ...           ...
# 3262        TERMINATED        STORES
# 3248        TERMINATED        STORES
# 4948        TERMINATED        STORES
# 3356        TERMINATED        STORES
# 4138        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
df.sample(20)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 6515        12/31/2009 0:00    12/18/1980        7/14/2006
# 3679        12/31/2012 0:00      8/6/1961        4/22/1996
# 1881        12/31/2012 0:00     1/31/1952        4/14/1991
# 6007        12/31/2009 0:00    12/22/1976         6/4/2004
# 5906        12/31/2008 0:00     1/27/1976       12/14/2003
# 3761        12/31/2014 0:00     1/22/1962        7/20/1996
# 2349        12/31/2014 0:00    10/10/1954        9/14/1992
# 2537        12/31/2012 0:00     11/4/1955         4/8/1993
# 6546        12/31/2012 0:00     3/12/1981        8/28/2006
# 2416        12/31/2011 0:00      2/7/1955       11/16/1992
# 6589        12/31/2010 0:00     6/22/1981       10/21/2006
# 5900        12/31/2007 0:00      1/6/1976        12/3/2003
# 3533        12/31/2006 0:00    10/28/1960       11/24/1995
# 2997        12/31/2014 0:00     2/20/1958        6/25/1994
# 3106        12/31/2014 0:00      9/7/1958        10/8/1994
# 7552        12/31/2011 0:00    11/28/1988        9/23/2010
# 1758        12/31/2012 0:00     5/12/1951       11/25/1990
# 5406        12/31/2013 0:00     1/13/1972       10/26/2001
# 7200        12/31/2011 0:00     4/29/1986        5/13/2009
# 6800        12/31/2011 0:00      4/5/1983        9/30/2007
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 6515                  1/1/1900   29                  3  New Westminster
# 3679                  1/1/1900   51                 16  New Westminster
# 1881                  1/1/1900   60                 21  New Westminster
# 6007                  1/1/1900   33                  5  New Westminster
# 5906                  1/1/1900   32                  5          Nanaimo
# 3761                  1/1/1900   52                 18          Quesnel
# 2349                  1/1/1900   60                 22           Surrey
# 2537                  1/1/1900   57                 19          Quesnel
# 6546                  1/1/1900   31                  6     Fort St John
# 2416                  1/1/1900   56                 19         Richmond
# 6589                  1/1/1900   29                  4  North Vancouver
# 5900                  1/1/1900   31                  4         Squamish
# 3533                  1/1/1900   46                 11        Vancouver
# 2997                  1/1/1900   56                 20         Victoria
# 3106                  1/1/1900   56                 20         Victoria
# 7552                  1/1/1900   23                  1          Burnaby
# 1758                  1/1/1900   61                 22   Port Coquitlam
# 5406                  1/1/1900   41                 12       Chilliwack
# 7200                  1/1/1900   25                  2        Vancouver
# 6800                  1/1/1900   28                  4  North Vancouver
#
#             department_name      job_title  store_name gender_short  \
# EmployeeID
# 6515                  Dairy   Dairy Person          21            M
# 3679                Produce  Produce Clerk          21            M
# 1881                  Meats    Meat Cutter          21            F
# 6007                  Dairy   Dairy Person          21            F
# 5906                  Dairy   Dairy Person          18            F
# 3761                Produce  Produce Clerk          28            M
# 2349                  Meats    Meat Cutter          31            F
# 2537                  Meats    Meat Cutter          28            F
# 6546                  Dairy   Dairy Person          12            M
# 2416                  Meats    Meat Cutter          29            M
# 6589        Processed Foods  Shelf Stocker          22            M
# 5900                  Dairy   Dairy Person          30            F
# 3533                  Meats    Meat Cutter          42            M
# 2997                Produce  Produce Clerk          46            M
# 3106                Produce  Produce Clerk          46            F
# 7552                  Dairy   Dairy Person           5            F
# 1758                  Meats  Meats Manager          25            F
# 5406                  Dairy   Dairy Person           6            F
# 7200                  Meats    Meat Cutter          44            M
# 6800        Processed Foods  Shelf Stocker          22            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  STATUS  \
# EmployeeID
# 6515              Male  Not Applicable  Not Applicable         2009  ACTIVE
# 3679              Male  Not Applicable  Not Applicable         2012  ACTIVE
# 1881            Female  Not Applicable  Not Applicable         2012  ACTIVE
# 6007            Female  Not Applicable  Not Applicable         2009  ACTIVE
# 5906            Female  Not Applicable  Not Applicable         2008  ACTIVE
# 3761              Male  Not Applicable  Not Applicable         2014  ACTIVE
# 2349            Female  Not Applicable  Not Applicable         2014  ACTIVE
# 2537            Female  Not Applicable  Not Applicable         2012  ACTIVE
# 6546              Male  Not Applicable  Not Applicable         2012  ACTIVE
# 2416              Male  Not Applicable  Not Applicable         2011  ACTIVE
# 6589              Male  Not Applicable  Not Applicable         2010  ACTIVE
# 5900            Female  Not Applicable  Not Applicable         2007  ACTIVE
# 3533              Male  Not Applicable  Not Applicable         2006  ACTIVE
# 2997              Male  Not Applicable  Not Applicable         2014  ACTIVE
# 3106            Female  Not Applicable  Not Applicable         2014  ACTIVE
# 7552            Female  Not Applicable  Not Applicable         2011  ACTIVE
# 1758            Female  Not Applicable  Not Applicable         2012  ACTIVE
# 5406            Female  Not Applicable  Not Applicable         2013  ACTIVE
# 7200              Male  Not Applicable  Not Applicable         2011  ACTIVE
# 6800            Female  Not Applicable  Not Applicable         2011  ACTIVE
#
#            BUSINESS_UNIT
# EmployeeID
# 6515              STORES
# 3679              STORES
# 1881              STORES
# 6007              STORES
# 5906              STORES
# 3761              STORES
# 2349              STORES
# 2537              STORES
# 6546              STORES
# 2416              STORES
# 6589              STORES
# 5900              STORES
# 3533              STORES
# 2997              STORES
# 3106              STORES
# 7552              STORES
# 1758              STORES
# 5406              STORES
# 7200              STORES
# 6800              STORES

# %% [markdown]
#  4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:

# %% [markdown]
# #### 4.B Group By Age

# %%
df.groupby('age').size()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
plt.hist(df.age,bins=50)
# Out:
# (array([ 158.,  408.,  703.,  815.,  960., 1111., 1197., 1210., 1235.,
#         1225., 1227., 1212.,    0., 1146., 1153., 1164., 1188., 1189.,
#         1176., 1149., 1156., 1142., 1130., 1135.,    0., 1152., 1150.,
#         1157., 1141., 1161., 1173., 1180., 1196., 1218., 1207., 1188.,
#         1188.,    0., 1159., 1168., 1154., 1130., 1130., 1128., 1109.,
#          757.,  712.,  667.,  646.,  593.]),
#  array([19.  , 19.92, 20.84, 21.76, 22.68, 23.6 , 24.52, 25.44, 26.36,
#         27.28, 28.2 , 29.12, 30.04, 30.96, 31.88, 32.8 , 33.72, 34.64,
#         35.56, 36.48, 37.4 , 38.32, 39.24, 40.16, 41.08, 42.  , 42.92,
#         43.84, 44.76, 45.68, 46.6 , 47.52, 48.44, 49.36, 50.28, 51.2 ,
#         52.12, 53.04, 53.96, 54.88, 55.8 , 56.72, 57.64, 58.56, 59.48,
#         60.4 , 61.32, 62.24, 63.16, 64.08, 65.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
plt.boxplot(df.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15a802f2af0>,
#   <matplotlib.lines.Line2D at 0x15a802f2dc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x15a801810d0>,
#   <matplotlib.lines.Line2D at 0x15a801813a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15a802f2820>],
#  'medians': [<matplotlib.lines.Line2D at 0x15a80181670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15a80181940>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
plt.scatter(df.age,df.length_of_service)

# %% [markdown]
# #### 5.D Print Statistical Summary of Age

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
